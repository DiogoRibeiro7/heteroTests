# %% [markdown]
# # HeteroTests tutorial
# This Jupyter notebook demonstrates basic usage of the package.

# %%
library(heteroTests)
data(boston_housing, package='heteroTests')
runDiagnostics(medv ~ lstat + rm + crim, boston_housing)
